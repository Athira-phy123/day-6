# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
hr_data=pd.read_csv(r"C:\Users\DELL\Downloads\\HR_comma_sep (1).csv")
hr_data.head(5)
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# ...

# %%
hr_data.shape
# Out:
# (14999, 10)

# %%
hr_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   sales                  14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
hr_data.nunique()
# Out:
# satisfaction_level        92
# last_evaluation           65
# number_project             6
# average_montly_hours     215
# time_spend_company         8
# Work_accident              2
# left                       2
# promotion_last_5years      2
# sales                     10
# salary                     3
# dtype: int64

# %%
hr_data.dtypes
# Out:
# satisfaction_level       float64
# last_evaluation          float64
# number_project             int64
# average_montly_hours       int64
# time_spend_company         int64
# Work_accident              int64
# left                       int64
# promotion_last_5years      int64
# sales                     object
# salary                    object
# dtype: object

# %%
## Check null values if any
hr_data.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# sales                    0
# salary                   0
# dtype: int64

# %%
hr_data.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'sales', 'salary'],
#       dtype='object')

# %% [markdown]
# # outliers

# %%
plt.figure(figsize=(15,15))
hr_data.boxplot()
plt.xticks(rotation=90)
# Out:
# (array([1, 2, 3, 4, 5, 6, 7, 8]),
#  [Text(1, 0, 'satisfaction_level'),
#   Text(2, 0, 'last_evaluation'),
#   Text(3, 0, 'number_project'),
#   Text(4, 0, 'average_montly_hours'),
#   Text(5, 0, 'time_spend_company'),
#   Text(6, 0, 'Work_accident'),
#   Text(7, 0, 'left'),
#   Text(8, 0, 'promotion_last_5years')])

# %%
corrmatrix=hr_data.corr()
plt.subplots(figsize=(20,8))
sns.heatmap(corrmatrix,vmin=-0.7,vmax=1,annot=True,linewidth=0.2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Expolatory Data analyis

# %% [markdown]
# # Viualization of data

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,6))
hr_data[['satisfaction_level','average_montly_hours']].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.pairplot(hr_data)

# %%
plt.figure(figsize=(10,10))
plt.hist(hr_data['sales'],color='red',rwidth=0.7)
# Out:
# (array([4140.,  767.,  739., 2720., 2229.,  630., 1227.,  902.,  858.,
#          787.]),
#  array([0. , 0.9, 1.8, 2.7, 3.6, 4.5, 5.4, 6.3, 7.2, 8.1, 9. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #the sales department has more employees than other departments and the management team has the least.

# %%
sales = hr_data.pivot_table(index = ['number_project'], aggfunc ='size')
plt.figure(figsize=(15,8))
plt.title('number_project', fontsize = 20)
sales.sort_values(ascending = False).head(5).plot(kind='bar')
# Out:
# <AxesSubplot:title={'center':'number_project'}, xlabel='number_project'>

# %% [markdown]
# Most employees have done at least 4 projects and only a few done 6 projects.

# %%
from numpy import average
from numpy import sum
plt.figure(figsize=(15,8))
sns.barplot (x = 'satisfaction_level', y = 'sales',data = hr_data, estimator=average)
# Out:
# <AxesSubplot:xlabel='satisfaction_level', ylabel='sales'>

# %% [markdown]
# # Preprocessing

# %% [markdown]
# # handling missing values

# %%
hr_data.isna().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# sales                    0
# salary                   0
# dtype: int64

# %% [markdown]
# # outliers

# %%
plt.figure(figsize=(15,15))
hr_data.boxplot()
plt.xticks(rotation=90)
# Out:
# (array([1, 2, 3, 4, 5, 6, 7, 8]),
#  [Text(1, 0, 'satisfaction_level'),
#   Text(2, 0, 'last_evaluation'),
#   Text(3, 0, 'number_project'),
#   Text(4, 0, 'average_montly_hours'),
#   Text(5, 0, 'time_spend_company'),
#   Text(6, 0, 'Work_accident'),
#   Text(7, 0, 'left'),
#   Text(8, 0, 'promotion_last_5years')])

# %%
plt.boxplot(hr_data['time_spend_company'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x179379758b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x17937975fd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x17937975520>],
#  'medians': [<matplotlib.lines.Line2D at 0x17937968760>],
#  'fliers': [<matplotlib.lines.Line2D at 0x17937968af0>],
#  'means': []}

# %%
Q1=np.percentile(hr_data['time_spend_company'],25,interpolation='midpoint')
Q2=np.percentile(hr_data['time_spend_company'],50,interpolation='midpoint')
Q3=np.percentile(hr_data['time_spend_company'],75,interpolation='midpoint')
print(Q1)
print(Q2)
print(Q3)
# Out:
# 3.0
# 3.0
# 4.0

# %%
IQR=Q3-Q1
lower_limit=Q1-1.5*IQR
upper_limit=Q3+1.5*IQR
print(lower_limit)
print(upper_limit)
# Out:
# 1.5
# 5.5

# %%
outlier=[]
for x in hr_data['time_spend_company']:
    if(x>upper_limit)or(x<lower_limit):
        outlier.append(x)
outlier
# Out:
# [6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
# ...

# %%
ind1=hr_data['time_spend_company']<lower_limit
hr_data=hr_data.drop(hr_data.loc[ind1].index)
hr_data
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
ind2=hr_data['time_spend_company']>upper_limit
hr_data=hr_data.drop(hr_data.loc[ind2].index)
hr_data
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# 5                    0.41             0.50               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 2                       272                   4              0     1
# ...

# %%
plt.boxplot(hr_data['time_spend_company'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x17938b64b50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x17938b55190>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x17938b647c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x17938b558b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x17938b55c40>],
#  'means': []}

# %%
dummies = pd.get_dummies(hr_data[['salary']])
features = pd.concat([hr_data.drop(['salary'],axis=1), dummies],axis=1)
features
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# 5                    0.41             0.50               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 2                       272                   4              0     1
# ...

# %%
hr_data['salary'].value_counts()
# Out:
# low       6831
# medium    5824
# high      1062
# Name: salary, dtype: int64

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(20,8))
hr_data.pivot_table(index = ['salary'], aggfunc ='size').sort_values(ascending = False).head(5).plot(kind='bar', ax=ax1).set_title("salary among all employee")
hr_data[hr_data.salary == "low"].pivot_table(index = ['sales'], aggfunc ='size').sort_values(ascending = False).head(5).plot(kind='bar', ax=ax2).set_title("low salary employees")
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(20,8))
hr_data[hr_data.salary == "high"].pivot_table(index = ['sales'], aggfunc ='size').sort_values(ascending = False).head(5).plot(kind='bar', ax=ax1).set_title("high salary employees")
hr_data[hr_data.salary == "medium"].pivot_table(index = ['sales'], aggfunc ='size').sort_values(ascending = False).head(5).plot(kind='bar', ax=ax2).set_title("medium salary employees")
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(20,8))
hr_data.pivot_table(index = ['time_spend_company'], aggfunc ='size').sort_values(ascending = False).head(5).plot(kind='bar', ax=ax1).set_title("time spend in years by all employees")
hr_data[hr_data.sales == "sales"].pivot_table(index = ['time_spend_company'], aggfunc ='size').sort_values(ascending = False).head(5).plot(kind='bar', ax=ax2).set_title("experience in the company among sales department")
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(20,8))
hr_data[hr_data.sales == "support"].pivot_table(index = ['time_spend_company'], aggfunc ='size').sort_values(ascending = False).head(5).plot(kind='bar', ax=ax1).set_title("experience in the company among technical department")
hr_data[hr_data.sales == "technical"].pivot_table(index = ['time_spend_company'], aggfunc ='size').sort_values(ascending = False).head(5).plot(kind='bar', ax=ax2).set_title("experience in the company among support department")
plt.show()

# %%
hr_data.hist(figsize=(20,20))
# Out:
# array([[<AxesSubplot:title={'center':'satisfaction_level'}>,
#         <AxesSubplot:title={'center':'last_evaluation'}>,
#         <AxesSubplot:title={'center':'number_project'}>],
#        [<AxesSubplot:title={'center':'average_montly_hours'}>,
#         <AxesSubplot:title={'center':'time_spend_company'}>,
#         <AxesSubplot:title={'center':'Work_accident'}>],
#        [<AxesSubplot:title={'center':'left'}>,
#         <AxesSubplot:title={'center':'promotion_last_5years'}>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# # standardization

# %%
y=hr_data['salary']
X=hr_data.drop(["salary"],axis=1)
X.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        13717.000000     13717.000000    13717.000000
# mean             0.611729         0.714338        3.783116
# std              0.248126         0.170571        1.243583
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.810000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          13717.000000        13717.000000   13717.000000  13717.000000
# mean             200.592768            3.164686       0.141576      0.245097
# std               49.915380            0.908507       0.348628      0.430161
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
from sklearn import preprocessing

# %%
standardisation=preprocessing.StandardScaler()

# %%
hr_data.select_dtypes(include=np.number)
X=standardisation.fit_transform(hr_data.select_dtypes(include=np.number),X)

# %%
X=pd.DataFrame(X)
X.describe()
# Out:
#                   0             1             2             3             4  \
# count  1.371700e+04  1.371700e+04  1.371700e+04  1.371700e+04  1.371700e+04
# mean  -1.135233e-15  2.180301e-16 -1.252010e-15 -6.491207e-18  1.292847e-15
# std    1.000036e+00  1.000036e+00  1.000036e+00  1.000036e+00  1.000036e+00
# min   -2.102749e+00 -2.077433e+00 -1.433906e+00 -2.095478e+00 -1.282025e+00
# 25%   -6.921260e-01 -9.048605e-01 -6.297485e-01 -8.933999e-01 -1.812779e-01
# 50%    1.139440e-01  3.319738e-02  1.744090e-01 -5.194516e-02 -1.812779e-01
# 75%    7.991035e-01  9.126266e-01  9.785665e-01  8.896827e-01  9.194696e-01
# max    1.564870e+00  1.674799e+00  2.586882e+00  2.191934e+00  2.020217e+00
#
#                   5             6             7
# count  1.371700e+04  1.371700e+04  1.371700e+04
# mean   6.792724e-15  3.356495e-14 -3.940001e-15
# std    1.000036e+00  1.000036e+00  1.000036e+00
# min   -4.061104e-01 -5.698018e-01 -1.334471e-01
# ...

# %% [markdown]
# # MODELING

# %%
from sklearn. model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=150,test_size=0.25)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score,precision_score

# %% [markdown]
# # KNeighborsClassifier

# %%
import warnings
warnings.filterwarnings('ignore')
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
acc_values=[]
neighbors=np.arange(3,15)
for k in neighbors:
    classifier=KNeighborsClassifier(n_neighbors=k,metric='minkowski')
    classifier.fit(X_train,y_train)
    y_pred=classifier.predict(X_test)
    acc=accuracy_score(y_test,y_pred)
    acc_values.append(acc)
acc_values
# Out:
# [0.5090379008746355,
#  0.5005830903790087,
#  0.4959183673469388,
#  0.5011661807580174,
#  0.4994169096209913,
#  0.5014577259475219,
#  0.4944606413994169,
#  0.4970845481049563,
#  0.49620991253644314,
#  0.5,
#  0.4897959183673469,
#  0.49533527696793]

# %%
# plt.plot(neighbors,acc_values,'o-')
plt.xlabel('k values')
plt.ylabel('accuracy')

# %%
## Creating an instance of KNeighborsClassifier with neighbours as 14
knn_model = KNeighborsClassifier(n_neighbors=4)
knn_model.fit(X_train, y_train)
knn_y_pred = knn_model.predict(X_test)
print("Train data accuracy:",accuracy_score(y_true = y_train, y_pred=knn_model.predict(X_train)))
print("Test data accuracy:",accuracy_score(y_true = y_test, y_pred=knn_y_pred))
# Out:
# Train data accuracy: 0.6967045785943424
# Test data accuracy: 0.5005830903790087

# %% [markdown]
# # DECISION TREE CLASSIFIER
